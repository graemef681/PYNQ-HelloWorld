# %%
import os
# Set the remote PYNQ device target
# Replace "xilinx-zcu104-20241" with your board's hostname or IP address
os.environ['PYNQ_REMOTE_DEVICES'] = "xilinx-zcu104-20241"  # or "<BOARD_IP>"
from remote_ui import SimpleCaptureUI
# Out:
# c:\Users\nqb15123\AppData\Local\Programs\Python\Python311\Lib\site-packages\pydantic\_internal\_config.py:345: UserWarning: Valid config keys have changed in V2:
# * 'underscore_attrs_are_private' has been removed
#   warnings.warn(message, UserWarning)

# %%
ui = SimpleCaptureUI(bitstream="pynqhelloworld.resizer.zcu104.bit", mode="webcam")
ui.render()
